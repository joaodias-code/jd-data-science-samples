# %%
import pandas as pd

# TODO: Set weight1, weight2, and bias
weight1 = 2
weight2 = 1
bias = -3


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [False, False, False, True]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))
# Out:
# Nice!  You got it all correct.
#
#  Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#        0          0                    -3                    0          Yes
#        0          1                    -2                    0          Yes
#        1          0                    -1                    0          Yes
#        1          1                     0                    1          Yes

# %%
import pandas as pd

# TODO: Set weight1, weight2, and bias
weight1 = 1
weight2 = -5
bias = 1


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [True, False, True, False]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))
# Out:
# Nice!  You got it all correct.
#
#  Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#        0          0                     1                    1          Yes
#        0          1                    -4                    0          Yes
#        1          0                     2                    1          Yes
#        1          1                    -3                    0          Yes

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_line_and_point(x1, x2, point):
    plt.plot(x1, x2, '-r' ) # label='y=2x+1')
    #plt.title('Graph of y=2x+1')
    plt.xlabel('x1', color='#1C2833')
    plt.ylabel('x2', color='#1C2833')
    #plt.legend(loc='upper left')
    plt.grid()

    plt.plot(point[0], point[1], 'bo', label='(1,1)')
    plt.show()


#aproximar a reta para que o ponto entre na outra área de classificação:
#multiplica pelo learning rate (0.1) o ponto e soma aos valores da equação:

#point: (1,1)
p1 = 1; p2=1
learning_rate = 0.1

w1 = 3
w2 = 4
b  = -10

# valores da reta: equação 3x1 + 4x2 - 10 = 0
x1 = np.linspace(0,5,100)
x2 = (-1*b - (w1*x1)) / w2
plot_line_and_point(x1,x2, (p1, p2))

#aproximando a reta do ponto: multiplicando pelo learning_rate
for qtd_aproximacao in range(11):
    w1 = w1 + (learning_rate * p1)
    w2 = w2 + (learning_rate * p2)
    b = b + (learning_rate * 1)
    print(w1, w2, b)
    x2 = (-1*b - (w1*x1)) / w2
    plot_line_and_point(x1,x2, (p1, p2))
# Out:
# 3.1 4.1 -9.9
# 3.2 4.199999999999999 -9.8
# 3.3000000000000003 4.299999999999999 -9.700000000000001
# 3.4000000000000004 4.399999999999999 -9.600000000000001
# 3.5000000000000004 4.499999999999998 -9.500000000000002
# 3.6000000000000005 4.599999999999998 -9.400000000000002
# 3.7000000000000006 4.6999999999999975 -9.300000000000002
# 3.8000000000000007 4.799999999999997 -9.200000000000003
# 3.900000000000001 4.899999999999997 -9.100000000000003
# 4.000000000000001 4.9999999999999964 -9.000000000000004
# 4.1000000000000005 5.099999999999996 -8.900000000000004
