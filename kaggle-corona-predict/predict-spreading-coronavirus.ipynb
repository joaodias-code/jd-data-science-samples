# %% [markdown]
# Novel Corona Virus 2019 Dataset
#
# Day level information on covid-19 affected cases
#
# https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset

# %%
import pandas as pd
import numpy as np
import os

os.getcwd()

ds = pd.read_csv('dataset/covid_19_data.csv')

ds.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
ds.head(100)
ds[ds['Province/State'] == 'Hubei']
# Out:
#        SNo ObservationDate Province/State  Country/Region  \
# 13      14      01/22/2020          Hubei  Mainland China
# 51      52      01/23/2020          Hubei  Mainland China
# 84      85      01/24/2020          Hubei  Mainland China
# 125    126      01/25/2020          Hubei  Mainland China
# 169    170      01/26/2020          Hubei  Mainland China
# 216    217      01/27/2020          Hubei  Mainland China
# 267    268      01/28/2020          Hubei  Mainland China
# 319    320      01/29/2020          Hubei  Mainland China
# 373    374      01/30/2020          Hubei  Mainland China
# 431    432      01/31/2020          Hubei  Mainland China
# 493    494      02/01/2020          Hubei  Mainland China
# 560    561      02/02/2020          Hubei  Mainland China
# 627    628      02/03/2020          Hubei  Mainland China
# 695    696      02/04/2020          Hubei  Mainland China
# 765    766      02/05/2020          Hubei  Mainland China
# ...
